# %%
# Importing the packages
import numpy as np
import pytesseract
from PIL import Image
import cv2
import re
import matplotlib.pyplot as plt
from tqdm import tqdm as tq
from transformers import AutoModelWithLMHead, AutoTokenizer , AutoModelForQuestionAnswering
import torch
import tensorflow
from transformers import pipeline
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # First Few things to run in file

# %% [markdown]
# # Making Functions

# %%
# %%time
# Importing the model
model = AutoModelForQuestionAnswering.from_pretrained("../input/question-answering-model/Question_Answering_Model")
tokenizer = AutoTokenizer.from_pretrained("../input/question-answering-model/Question_Answering_Model")
question_model = pipeline("question-answering",use_fast=True,model=model,tokenizer=tokenizer,device=0)# Making a list of questions related to the dataset
# Text summarizar model and tokenizer
model=AutoModelWithLMHead.from_pretrained('../input/summarization-model-4/Text Summarizer')
tokenizer=AutoTokenizer.from_pretrained('../input/summarization-model-4/Text Summarizer')
summarizer=pipeline('summarization',model=model,tokenizer=tokenizer,device=0)
# Out:
# CPU times: user 20.5 s, sys: 3.16 s, total: 23.6 s
# Wall time: 47.5 s

# %%
def autocropping_text(text,padding_size=10,show_image=False,image_name="Image"):
    # Autocropping the image using pytesseract as well
    d = pytesseract.image_to_data(text, output_type=Output.DICT)

    # Working on the left point first
    left=d['left']
    left.sort()
    left=[i for i in left if i!=0]
    if min(left)>padding_size:
        lef=min(left)-padding_size
    else:
        lef=0

    # Working on the right point
    right=d['left']+d['width']
    right.sort(reverse=True)
    right=[i for i in right if i!=text.shape[1]]
    if max(right)+padding_size<text.shape[1]:
        righ=max(right)+padding_size
    else:
        righ=text.shape[1]

    #Working on the top
    top=d['top']
    top.sort()
    top=[i for i in top if i!=0]
    to=min(top)
    if to-padding_size >0 :
        to=to-padding_size
    else:
        to=0

    # Working with bottom
    bottom=d['top']+d['height']
    bottom.sort(reverse=True)
    bottom=[i for i in bottom if i!=text.shape[0]]
    bot=max(bottom)
    if bot+padding_size<text.shape[0]:
        bot=bot+padding_size
    else:
        bot=text.shape[0]

    # Cropping the image now
    crop_img = text[to:bot, lef:righ]

    # Showing the image now
    if show_image:
        plt.figure(figsize=(18,8))
        plt.imshow(crop_img)
    
    # Saving the image for future reference 
    cv2.imwrite(image_name+".jpg",crop_img)

# %%
# Function to translate 
def translate(tex,lang1="English",lang2="Hindi"):
    path='../input/english-to-hindi-model/'+lang1+'_to_'+lang2
    model = AutoModelWithLMHead.from_pretrained(path)
    tokenizer = AutoTokenizer.from_pretrained(path)
    l1=lang1.lower()[:2]
    l2=lang2.lower()[:2]
    translation_path="translation_"+l1+"_to_"+l2
    translate=pipeline(translation_path,model=model,tokenizer=tokenizer,device=0)
    texing=tex.split('.')
    tex_total=[]
    for i in tq(texing) :
        tex_total.append(translate(i, max_length=80)[0]['translation_text'])
    print('.'.join(tex_total))

# %%
def question(tex,questions) :
    answer=question_model(context=tex,question=questions,max_ans_length=12)
    return answer['answer']

# %%
def summarize(tex,min_length=5,max_length=50):
    return summarizer(tex, min_length=min_length, max_length=max_length)[0]['summary_text']

# %%
# def to_another_image()

# %% [markdown]
# # Using Functions

# %%
# %%time
text=read_image("../input/textimage/IMG_20210125_155407__01.png")
tex=pytesseract.image_to_string(text)
print(tex)

# %%
# Autocropping the image
autocropping_text(text,20,show_image=True)

# %%
translate(tex,"English","French")
# Out:
# 100%|██████████| 27/27 [00:06<00:00,  4.03it/s]
# LE DARK LOND ASCENDANT 1] «Severus, ici, dit Voldemort, indiquant le siège sur sa droite immédiate.«Yaxley — à côté de Dolohov.Les deux hommes ont pris leurs places.La plupart des yeux autour de la table suivirent Snape et c'est à lui que Voldemort parla en premier."Sor, mon Seigneur, l'Ordre du Phoenix a l'intention de déplacer Harry Potter de son lieu actuel de sécurité samedi prochain, à la tombée de la nuit.L'intérêt autour de la table aiguisé palpablement: certains raidis, d'autres fidgeted, tous regardant à Snape et Voldemort.«Samedi.Le présent règlement entre en vigueur le jour suivant celui de sa publication au Journal officiel de l'Union européenne..Le présent règlement entre en vigueur le jour suivant celui de sa publication au Journal officiel de l'Union européenne..à la tombée de la nuit, Voldemort répété.Ses yeux rouges s'attachèrent aux Noirs de Snape avec une telle intensité que quelques-uns des guetteurs regardèrent ailleurs, apparemment craignant qu'ils soient eux-mêmes brûlés par la férocité du regard.Snape, cependant, a regardé calmement de nouveau dans le visage de Voldemort, et, après un moment ou deux, Voldemort , bouche sans lèvres courbée en quelque chose comme un sourire.«Bien.Très bien..Et cette information vient — "D'après la source dont nous avons parlé," dit Snape.Mon Seigneur.Yaxley s'était penché vers l'avant pour regarder vers le bas la longue table à Voldemort et Snape.Tous les visages tournés vers lui.«Mon Seigneur, j'ai entendu différemment.Yaxley a attendu, mais Voldemort n'a pas parlé, alors il a continué, Dawlish, l'Auror, laisser glisser que Potter ne sera pas déplacé jusqu'au trentième, la nuit avant que le garçon a eu dix-sept ans."Snape souriait".«Ma source m'a dit qu'il y avait des plans pour jeter une fausse piste; cela doit être.Sans doute un Confundus Charm a été placé sur Dawlish.Ce ne serait pas la première fois, il est connu pour être sensible.«Je vous assure, mon Seigneur, que Dawlish semblait tout à fait certain, dit Yaxley.S'il a été Confinancé, naturellement il est certain, dit Snape.«Je vous assure, Yaxley, que le bureau d'Auror ne jouera plus

# %%
question(tex,"who is harry?")
# Out:
# 'Harry\nPotter'

# %%
summarize(tex,max_length=50)
# Out:
# " Voldemort and Snape sat at the same table at Voldemort's request to discuss Harry Potter's whereabouts . Voldemort's red eyes looked at Snape with such intensity that some of the watchers looked away, apparently fearful that they themselves would be scorched"
